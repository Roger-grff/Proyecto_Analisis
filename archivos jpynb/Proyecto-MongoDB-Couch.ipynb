# %%
import pandas as pd
import json

# %%
from pymongo import MongoClient

# %%
with open("dummy_data.csv", 'r', encoding='utf-8') as archivo:
    df_file1 = pd.read_csv(archivo)

df_file1.head()
# Out:
#    age      gender  time_spent   platform  interests        location  \
# 0   56        male           3  Instagram     Sports  United Kingdom
# 1   46      female           2   Facebook     Travel  United Kingdom
# 2   32        male           8  Instagram     Sports       Australia
# 3   60  non-binary           5  Instagram     Travel  United Kingdom
# 4   25        male           1  Instagram  Lifestlye       Australia
#
#   demographics         profession  income  indebt  isHomeOwner  Owns_Car
# 0        Urban  Software Engineer   19774    True        False     False
# 1        Urban            Student   10564    True         True      True
# 2    Sub_Urban   Marketer Manager   13258   False        False     False
# 3        Urban            Student   12500   False         True     False
# 4        Urban  Software Engineer   14566   False         True      True

# %%
#Limpiar dataFRAME con pandas
df_file1 = df_file1.dropna()  # Eliminar filas con valores NaN
df_file1 = df_file1.drop_duplicates()  # Eliminar filas duplicadas
df_file1 = df_file1.reset_index(drop=True)  # Reiniciar el índice del DataFrame
# Mostrar las primeras filas del DataFrame limpio
df_file1.head()
# Out:
#    age      gender  time_spent   platform  interests        location  \
# 0   56        male           3  Instagram     Sports  United Kingdom
# 1   46      female           2   Facebook     Travel  United Kingdom
# 2   32        male           8  Instagram     Sports       Australia
# 3   60  non-binary           5  Instagram     Travel  United Kingdom
# 4   25        male           1  Instagram  Lifestlye       Australia
#
#   demographics         profession  income  indebt  isHomeOwner  Owns_Car
# 0        Urban  Software Engineer   19774    True        False     False
# 1        Urban            Student   10564    True         True      True
# 2    Sub_Urban   Marketer Manager   13258   False        False     False
# 3        Urban            Student   12500   False         True     False
# 4        Urban  Software Engineer   14566   False         True      True

# %%
#Conectar a MongoDB
client = MongoClient('mongodb://localhost:27017/')
db = client['Hobbit']
collection = db['Pasatiempos']
# Insertar el DataFrame en MongoDB
collection.insert_many(df_file1.to_dict('records'))

# Consultar los datos insertados
resultados = collection.find()

# %%
with open("olympic_medals.csv", 'r', encoding='utf-8') as archivo:
    df_file2 = pd.read_csv(archivo)

df_file2.head()
# Out:
#   discipline_title     slug_game    event_title event_gender medal_type  \
# 0          Curling  beijing-2022  Mixed Doubles        Mixed       GOLD
# 1          Curling  beijing-2022  Mixed Doubles        Mixed       GOLD
# 2          Curling  beijing-2022  Mixed Doubles        Mixed     SILVER
# 3          Curling  beijing-2022  Mixed Doubles        Mixed     SILVER
# 4          Curling  beijing-2022  Mixed Doubles        Mixed     BRONZE
#
#   participant_type participant_title  \
# 0         GameTeam             Italy
# 1         GameTeam             Italy
# 2         GameTeam            Norway
# 3         GameTeam            Norway
# 4         GameTeam            Sweden
#
#                                          athlete_url     athlete_full_name  \
# 0  https://olympics.com/en/athletes/stefania-cons...  Stefania CONSTANTINI
# 1      https://olympics.com/en/athletes/amos-mosaner          Amos MOSANER
# 2  https://olympics.com/en/athletes/kristin-skaslien      Kristin SKASLIEN
# ...

# %%
#Limpiar dataFRAME con pandas
df_file1 = df_file1.dropna()  # Eliminar filas con valores NaN
df_file1 = df_file1.drop_duplicates()  # Eliminar filas duplicadas
df_file1 = df_file1.reset_index(drop=True)  # Reiniciar el índice del DataFrame
# Mostrar las primeras filas del DataFrame limpio
df_file1.head()
# Out:
#   discipline_title     slug_game    event_title event_gender medal_type  \
# 0          Curling  beijing-2022  Mixed Doubles        Mixed       GOLD
# 1          Curling  beijing-2022  Mixed Doubles        Mixed       GOLD
# 2          Curling  beijing-2022  Mixed Doubles        Mixed     SILVER
# 3          Curling  beijing-2022  Mixed Doubles        Mixed     SILVER
# 4          Curling  beijing-2022  Mixed Doubles        Mixed     BRONZE
#
#   participant_type participant_title  \
# 0         GameTeam             Italy
# 1         GameTeam             Italy
# 2         GameTeam            Norway
# 3         GameTeam            Norway
# 4         GameTeam            Sweden
#
#                                          athlete_url     athlete_full_name  \
# 0  https://olympics.com/en/athletes/stefania-cons...  Stefania CONSTANTINI
# 1      https://olympics.com/en/athletes/amos-mosaner          Amos MOSANER
# 2  https://olympics.com/en/athletes/kristin-skaslien      Kristin SKASLIEN
# ...

# %%
#Conectar a MongoDB
client = MongoClient('mongodb://localhost:27017/')
db = client['Hobbit']
collection = db['Olympic']
# Insertar el DataFrame en MongoDB
collection.insert_many(df_file1.to_dict('records'))

# Consultar los datos insertados
resultados = collection.find()

# %%
import pandas as pd
from pymongo import MongoClient

# Cargar archivo JSON (asegúrate que sea una lista de objetos)
df = pd.read_json("Dataset_v3.json")

# Convertir a lista de diccionarios
documentos = df.to_dict(orient="records")

# Conectar a MongoDB Atlas
uri = "mongodb+srv://diegomontaluisa01:Aries1840@cluster0.zwefwzj.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"
cliente = MongoClient(uri)

# Acceder a la base y colección
db = cliente["ProyectoDatos"]
coleccion = db["Noticias"]

# Insertar documentos
resultado = coleccion.insert_many(documentos)

print("✅ Se insertaron los siguientes IDs:")
print(resultado.inserted_ids)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[55], line 5
#       2 from pymongo import MongoClient
#       4 # Cargar archivo JSON (asegúrate que sea una lista de objetos)
# ----> 5 df = pd.read_json("Dataset_v3.json")
#       7 # Convertir a lista de diccionarios
#       8 documentos = df.to_dict(orient="records")
#
# File c:\Users\User\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\json\_json.py:815, in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, precise_float, date_unit, encoding, encoding_errors, lines, chunksize, compression, nrows, storage_options, dtype_backend, engine)
#     813     return json_reader
#     814 else:
# --> 815     return json_reader.read()
#
# File c:\Users\User\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\json\_json.py:1014, in JsonReader.read(self)
# ...

# %%
# De csv a json
df = pd.read_csv('olympic_results.csv')
df.to_json('olympic_results.json', orient='records', lines=True)
with open('olympic_results.json', 'r', encoding='utf-8') as file:
    documentos = [json.loads(line) for line in file]

# %%
import json
from couchbase.cluster import Cluster
from couchbase.options import ClusterOptions
from couchbase.auth import PasswordAuthenticator
from couchbase.exceptions import CouchbaseException

# Conexión
cluster = Cluster("couchbase://localhost", ClusterOptions(
    PasswordAuthenticator("Diego", "Aries1840")))
bucket = cluster.bucket("Noticias")
coleccion = bucket.default_collection()

# Leer lista de objetos
with open("Noticias.json", "r", encoding="utf-8") as f:
    lista = json.load(f)

# Subir cada documento
for doc in lista:
    doc_id = doc.get("id")
    if doc_id:
        coleccion.upsert(doc_id, doc)
        print(f"✅ Documento '{doc_id}' subido.")
    else:
        print(" Documento sin ID, omitido.")
# Out:
#  Documento sin ID, omitido.
#  Documento sin ID, omitido.
#  Documento sin ID, omitido.
#  Documento sin ID, omitido.
#  Documento sin ID, omitido.
#  Documento sin ID, omitido.
#  Documento sin ID, omitido.
#  Documento sin ID, omitido.
#  Documento sin ID, omitido.
#  Documento sin ID, omitido.
#  Documento sin ID, omitido.
#  Documento sin ID, omitido.
#  Documento sin ID, omitido.
#  Documento sin ID, omitido.
#  Documento sin ID, omitido.
#  Documento sin ID, omitido.
#  Documento sin ID, omitido.
#  Documento sin ID, omitido.
#  Documento sin ID, omitido.
#  Documento sin ID, omitido.
#  Documento sin ID, omitido.
#  Documento sin ID, omitido.
#  Documento sin ID, omitido.
#  Documento sin ID, omitido.
#  Documento sin ID, omitido.
#  Documento sin ID, omitido.
#  Documento sin ID, omitido.
#  Documento sin ID, omitido.
#  Documento sin ID, omitido.
#  Documento sin ID, omitido.
#  Documento sin ID, omitido.
#  Documento sin ID, omitido.
#  Documento sin ID, omitido.
# ...

# %%
from couchbase.cluster import Cluster
from couchbase.options import ClusterOptions, QueryOptions
from couchbase.auth import PasswordAuthenticator
from couchbase.exceptions import CouchbaseException

# Conexión
cluster = Cluster("couchbase://localhost", ClusterOptions(
    PasswordAuthenticator("admin", "123456")))  # Cambia a tu usuario y clave
bucket = cluster.bucket("default")  # Cambia a tu bucket
coleccion = bucket.default_collection()

try:
    # Consulta N1QL para traer todos los documentos del bucket
    consulta = "SELECT META().id, * FROM `default`"  # cambia 'default' si es otro bucket
    resultado = cluster.query(consulta, QueryOptions())

    print("📄 Documentos en el bucket:")
    for fila in resultado:
        print(fila)

except CouchbaseException as e:
    print("⚠️ Error al consultar:", e)

# %%
import pyodbc

# Parámetros de conexión
server = 'NOMBRE_DEL_SERVIDOR'  # Ejemplo: 'localhost\\SQLEXPRESS'
database = 'NOMBRE_DE_LA_BASE_DE_DATOS'
username = 'USUARIO'  # Si usas autenticación de SQL Server
password = 'CONTRASEÑA'  # Si usas autenticación de SQL Server

# Cadena de conexión
conn_str = (
    'DRIVER={ODBC Driver 17 for SQL Server};'
    f'SERVER={server};'
    f'DATABASE={database};'
    f'UID={username};'
    f'PWD={password}'
)

# Conexión
try:
    conn = pyodbc.connect(conn_str)
    cursor = conn.cursor()
    print("✅ Conexión exitosa a SQL Server")

    # Ejemplo: Ejecutar una consulta
    cursor.execute("SELECT TOP 10 * FROM TuTabla")
    for row in cursor.fetchall():
        print(row)

    conn.close()
except Exception as e:
    print("❌ Error al conectar a SQL Server:", e)
